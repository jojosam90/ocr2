# %% [markdown]
# <a href="https://colab.research.google.com/github/jojosam90/ocr2/blob/main/docTR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
  #!git clone https://github.com/mindee/doctr.git
# Out:
# fatal: destination path 'doctr' already exists and is not an empty directory.

# %%
# !!pip install -e doctr/.[tf]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/doctr
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# WARNING: python-doctr 0.6.1a0 does not provide the extra 'tf'
# ...
#   Running setup.py develop for python-doctr
# ...

# %%
import json
from doctr.io import DocumentFile
from doctr.models import ocr_predictor

# %%
model = ocr_predictor(det_arch='db_resnet50',reco_arch='crnn_vgg16_bn',pretrained=True)
image = DocumentFile.from_images("/content/test/receipt.jpg")

result = model(image)
result_json = result.export()
print(json.dumps(result_json,indent=4))
result.show(image)
# Out:
# {
#     "pages": [
#         {
#             "page_idx": 0,
#             "dimensions": [
#                 3879,
#                 2856
#             ],
#             "orientation": {
#                 "value": null,
#                 "confidence": null
#             },
#             "language": {
#                 "value": null,
#                 "confidence": null
#             },
#             "blocks": [
#                 {
#                     "geometry": [
#                         [
#                             0.4306640625,
#                             0.1083984375
#                         ],
#                         [
#                             0.72265625,
#                             0.1611328125
#                         ]
#                     ],
#                     "lines": [
#                         {
#                             "geometry": [
#                                 [
#                                     0.4326171875,
# ...
